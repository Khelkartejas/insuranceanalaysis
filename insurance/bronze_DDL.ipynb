# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS insurancetej.bronze;

# %%
# %sql
create table if not exists insurancetej.bronze.Claims(
RowSequence_FimaNfipClaims  long,
metadata_count  long,
metadata_entityname  string,
metadata_filter  string,
metadata_format  string,
metadata_metadata  boolean,
metadata_orderby  string,
metadata_rundate  string,
metadata_select  string,
metadata_skip  long,
metadata_top  long,
metadata_url  string,
metadata_version  string,
FimaNfipClaims_agricultureStructureIndicator  boolean,
FimaNfipClaims_amountPaidOnBuildingClaim  double,
FimaNfipClaims_amountPaidOnContentsClaim  double,
FimaNfipClaims_amountPaidOnIncreasedCostOfComplianceClaim  double,
FimaNfipClaims_asOfDate  string,
FimaNfipClaims_baseFloodElevation  double,
FimaNfipClaims_basementEnclosureCrawlspaceType  long,
FimaNfipClaims_buildingDamageAmount  long,
FimaNfipClaims_buildingDeductibleCode  string,
FimaNfipClaims_buildingDescriptionCode  long,
FimaNfipClaims_buildingPropertyValue  long,
FimaNfipClaims_buildingReplacementCost  long,
FimaNfipClaims_causeOfDamage  string,
FimaNfipClaims_censusBlockGroupFips  string,
FimaNfipClaims_censusTract  string,
FimaNfipClaims_condominiumCoverageTypeCode  string,
FimaNfipClaims_contentsDamageAmount  long,
FimaNfipClaims_contentsDeductibleCode  string,
FimaNfipClaims_contentsPropertyValue  long,
FimaNfipClaims_contentsReplacementCost  long,
FimaNfipClaims_countyCode  string,
FimaNfipClaims_crsClassificationCode  long,
FimaNfipClaims_dateOfLoss  string,
FimaNfipClaims_disasterAssistanceCoverageRequired  long,
FimaNfipClaims_elevatedBuildingIndicator  boolean,
FimaNfipClaims_elevationCertificateIndicator  string,
FimaNfipClaims_elevationDifference  long,
FimaNfipClaims_eventDesignationNumber  string,
FimaNfipClaims_ficoNumber  long,
FimaNfipClaims_floodCharacteristicsIndicator  long,
FimaNfipClaims_floodEvent  string,
FimaNfipClaims_floodWaterDuration  long,
FimaNfipClaims_floodZoneCurrent  string,
FimaNfipClaims_floodproofedIndicator  boolean,
FimaNfipClaims_houseWorship  boolean,
FimaNfipClaims_iccCoverage  long,
FimaNfipClaims_id  string,
FimaNfipClaims_latitude  double,
FimaNfipClaims_locationOfContents  long,
FimaNfipClaims_longitude  double,
FimaNfipClaims_lowestAdjacentGrade  double,
FimaNfipClaims_lowestFloorElevation  double,
FimaNfipClaims_netBuildingPaymentAmount  double,
FimaNfipClaims_netContentsPaymentAmount  double,
FimaNfipClaims_netIccPaymentAmount  double,
FimaNfipClaims_nfipCommunityName  string,
FimaNfipClaims_nfipCommunityNumberCurrent  string,
FimaNfipClaims_nfipRatedCommunityNumber  string,
FimaNfipClaims_nonPaymentReasonBuilding  string,
FimaNfipClaims_nonPaymentReasonContents  string,
FimaNfipClaims_nonProfitIndicator  boolean,
FimaNfipClaims_numberOfFloorsInTheInsuredBuilding  long,
FimaNfipClaims_numberOfUnits  long,
FimaNfipClaims_obstructionType  long,
FimaNfipClaims_occupancyType  long,
FimaNfipClaims_originalConstructionDate  string,
FimaNfipClaims_originalNBDate  string,
FimaNfipClaims_policyCount  long,
FimaNfipClaims_postFIRMConstructionIndicator  boolean,
FimaNfipClaims_primaryResidenceIndicator  boolean,
FimaNfipClaims_rateMethod  string,
FimaNfipClaims_ratedFloodZone  string,
FimaNfipClaims_rentalPropertyIndicator  boolean,
FimaNfipClaims_replacementCostBasis  string,
FimaNfipClaims_reportedCity  string,
FimaNfipClaims_reportedZipCode  string,
FimaNfipClaims_smallBusinessIndicatorBuilding  boolean,
FimaNfipClaims_state  string,
FimaNfipClaims_stateOwnedIndicator  boolean,
FimaNfipClaims_totalBuildingInsuranceCoverage  long,
FimaNfipClaims_totalContentsInsuranceCoverage  long,
FimaNfipClaims_waterDepth  long,
FimaNfipClaims_yearOfLoss  long,
Added_By string,
Added_On timestamp,
Modified_By string,
Modified_On timestamp
)

# %%
# %sql
create table if not exists insurancetej.bronze.PenetrationRates(
RowSequence_NfipResidentialPenetrationRates  long,
metadata_count  long,
metadata_entityname  string,
metadata_filter  string,
metadata_format  string,
metadata_metadata  boolean,
metadata_orderby  string,
metadata_rundate  string,
metadata_select  string,
metadata_skip  long,
metadata_top  long,
metadata_url  string,
metadata_version  string,
NfipResidentialPenetrationRates_asOfDate  string,
NfipResidentialPenetrationRates_county  string,
NfipResidentialPenetrationRates_fipsCode  string,
NfipResidentialPenetrationRates_id  string,
NfipResidentialPenetrationRates_resContractsInForce  long,
NfipResidentialPenetrationRates_resContractsInForceSfha  long,
NfipResidentialPenetrationRates_resPenetrationRate  double,
NfipResidentialPenetrationRates_resPenetrationRateSfha  double,
NfipResidentialPenetrationRates_state  string,
NfipResidentialPenetrationRates_totalResStructures  long,
NfipResidentialPenetrationRates_totalResStructuresSfha  long,
Added_By string,
Added_On timestamp,
Modified_By string,
Modified_On timestamp
)
