# %%
# %sql
create schema insurancetej.gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS insurancetej.gold.DIM_PENETRATION_RATES(
PENETRATION_RATES_KEY	INT,
PENETRATION_RATES_CODE	INT,
PENETRATION_RATES_URL	STRING,
PENETRATION_RATES_COUNTY	STRING,
PENETRATION_RATES_TOTAL_RESTRUCTURES	INT,
PENETRATION_RATES_STATE	STRING,
ADDED_BY	STRING,
ADDED_ON	TIMESTAMP,
MODIFIED_BY	STRING,
MODIFIED_ON	TIMESTAMP
)

# %%
# %sql
CREATE TABLE IF NOT EXISTS insurancetej.gold.FACT_CLAIMS(
CLAIMS_KEY	INT,
CLAIMS_CODE	INT,
CLAIMS_ENTITY_NAME	STRING,
CLAIM_SETTLEMENT_CASE	STRING,
CLAIM_APPROVAL_STATUS	STRING,
CLAIM_ID	STRING,
ADDED_BY	STRING,
ADDED_ON	TIMESTAMP,
MODIFIED_BY	STRING,
MODIFIED_ON	TIMESTAMP
)
